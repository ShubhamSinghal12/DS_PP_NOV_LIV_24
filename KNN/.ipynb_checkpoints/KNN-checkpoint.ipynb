# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# !pip install scikit-learn

# %%
x = pd.read_csv("xdata.csv",index_col=False,usecols=[1,2])
y = pd.read_csv("ydata.csv",index_col=False,usecols=[1])

X_data,y_data = x.values,y.values.reshape(-1)
print(X_data.shape,y_data.shape)
# Out:
# (399, 2) (399,)

# %%
split = 0.8

# x_train,x_test = X_data[:0.8*(len(X_data))],X_data[0.8*(len(X_data)):]
# y_train,y_test = y_data[:0.8*(len(X_data))],y_data[0.8*(len(X_data)):]

x_train,x_test , y_train,y_test = train_test_split(X_data,y_data)

# %%
plt.scatter(X_data[y_data == 0][:,0],X_data[y_data == 0][:,1],c='blue',label = '0')
plt.scatter(X_data[y_data == 1][:,0],X_data[y_data == 1][:,1],c='y',label = '1')
plt.scatter(2,3,c='r')
plt.legend()
plt.show()

# %%
T = np.array([2,3])

# %%
def distance(t,i):
   return np.sqrt(np.sum((t-i)**2))

# %%
distance(X_data[0],T)
# Out:
# 1.678434612099308

# %%
k = 5
def predict_1(T):
    dist = []
    for p in X_data:
        dist.append(distance(T,p))

    knear = np.argsort(dist)[:k]
    klabels = []
    for p in knear:
        klabels.append(y_data[p])

    labels,counts = np.unique(klabels,return_counts=True)
    return labels[np.argmax(counts)]

# %%
predict_1(T)
# Out:
# 0.0

# %%
class KNNClassifier:
    def __init__(self,k = 5):
        self.k = k
        
    def fit(self,x,y):
        self.X = x
        self.y = y
        
    def distance_formula(self,p1,p2):
        return np.sqrt(np.sum((p1-p2)**2))
        
    def predict_1(self,t):
        dist = []
        for p in self.X:
            dist.append(distance(t,p))
    
        knear = np.argsort(dist)[:k]
        klabels = []
        for p in knear:
            klabels.append(self.y[p])
    
        labels,counts = np.unique(klabels,return_counts=True)
        predLabel = labels[np.argmax(counts)]
        prob = np.max(counts)/self.k
        # print("Probability:", prob)
        
        return predLabel 
        # For Regression return np.mean(klables)

    def predict(self,t):
        predictions = []
        for i in range(len(t)):
            predictions.append(self.predict_1(t[i]))
        return np.array(predictions)

    def accuracy(ytrue,ypred):
        return np.mean(ytrue==ypred)

# %%
# clf = KNNClassifier(5)
clf = KNeighborsClassifier(5)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
# print(KNNClassifier.accuracy(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
t = np.array([2,3])
plt.scatter(t[0],t[1],c='r',label="T")
plt.scatter(X_data[y_data == 0][:,0],X_data[y_data == 0][:,1],c='blue',label = '0')
plt.scatter(X_data[y_data == 1][:,0],X_data[y_data == 1][:,1],c='y',label = '1')
plt.legend()
plt.show()

# %%
clf = KNNClassifier(5)
clf.fit(X_data,y_data)
clf.predict_1(t)
# Out:
# 0.0

# %%
# x_train,x_test,y_train,y_test = X_data[:320],X_data[320:],y_data[:320],y_data[320:]
x_train,x_test,y_train,y_test = train_test_split(X_data,y_data,train_size=0.8)
# x_train[0]

# %%
clf = KNNClassifier(5)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

# %%
acc = np.sum(y_pred == y_test)/y_test.shape[0]

# %%
acc = accuracy_score(y_test,y_pred)

# %%
acc
# Out:
# 1.0

# %%
x = pd.read_csv("xdata.csv",index_col=False,usecols=[1,2])
y = pd.read_csv("ydata.csv",index_col=False,usecols=[1])

X_data,y_data = x.values,y.values.reshape(-1)

# %%
std = StandardScaler()
X_data = std.fit_transform(X_data)

# %%
plt.scatter(X_data[y_data == 0][:,0],X_data[y_data == 0][:,1],c='blue',label = '0')
plt.scatter(X_data[y_data == 1][:,0],X_data[y_data == 1][:,1],c='y',label = '1')
plt.legend()
plt.show()

# %%
x_train,x_test,y_train,y_test = train_test_split(X_data,y_data,train_size=0.8)
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 1.0
